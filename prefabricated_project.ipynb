# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Привет! Рад буду вновь поработать над проектом вместе с тобой :)**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если удобнее на «вы», просто напиши, и мы сменим стиль общения.
#
# Я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Просьба не менять их местами и не удалять, чтобы наша работа над проектом была максимально продуктивной. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их исправления проект не будет принят. Я оцениваю не только код, но и его интерпретацию, а также соответствие техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации, которые стоит учесть. Это не критично, но поможет сделать работу лучше. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (Сode/Markdown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Сборный проект  по исследованию продаж компьютерных игр

# %% [markdown]
# **Описание проекта:**
#
# В интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры, из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
#
#
# **Цель проекта:**
# Перед нами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
#
#
# **Ход работы:**
#
# - Подготовка данных:загрузка и изучение общей информации из предоставленного датасета.
# - Предобработка данных:обработка пропущенных значений,корректировака типап данных,дубликатов,наименований столбцов и других аномалий.
# - Исследователий анализ данных:изучение основных параметров игр,их распределения,зависимости и корреляции.
# - Составление портрета пользователя каждого региона:выявление 5 популярных жанров видеоигр,5 популярных платформ,распередение игр по возрастному рейтингу ESRB.
# - Проверка гипотез:формулирование и проверка гипотез.
#
# **Общий вывод:** резюмирование полученных результатов,формулировка ключевых выводов и рекомендаций.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Здорово, что есть описение проекта. Это поможет быстро вспомнить, о чем проект, если ты к нему вернешься спустя какое-то время.
#
# Данный блок можно расширить при помощи плана работы и описания данных. Посмотреть подробнее про вступительный блок можно в разделе "Полезные инструкции в учебе" блока "Оформление проекта".
#
#
# </div>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Импортируем библиотеки:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %% [markdown]
# ### Запишем csv-файл в переменную:

# %%
games = pd.read_csv("/datasets/games.csv")

# %% [markdown]
# ### Выведем на экран первые 10 строк датафрейма games  и общую информацию по нему:

# %%
display(games.head(10))
games.info()
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# Вывод:при загрузке данных и выводе общей информации по датафрейму были замечены следующие проблемы:
#
# - В датафрейме наименования столбцов не соответствую общепринятому стандарту написания кода PEP 8(имеются заглавные буквы);
# - Типы данных в столбцах  "Year_of_Release" и "User_Score" не соответвует логически обоснованным (информация в  столбце "Year_of_Release" представляет целое число  со значением года типа float,то есть,логично использовать тип int,так как значение года не может быть дробным;информация в  столбце "User_Score" представляет строку Object,хотя сама оценка представляет из себя число);
# - Имееются пропуски в столбцах "Name","Year_of_Release","Genre","Critic_Score","User_Score","Rating".

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Здесь у нас заканчивается вводная часть ознакомления с данными. Основная информация получена. Было бы неплохо также привести небольшое заключение по объему данных и основных ошибках, которые уже были обнаружены на этой стадии (типы данных, пропуски, названия колонок и др).
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Вывод добавлен выше.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ##  Предобработка данных

# %% [markdown]
# ### Заменим названия столбцов (приведем к нижнему регистру):

# %%
games = games.rename(columns = {i:i.lower() for i in games.columns})#Создадим генератор словарей и передадим его в качестве словоря новых значений метода rename
display(games.head(10))#Выведем на экран первые 10 строк обновленного датафрейма
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# ### Предобработаем каждые столбец по отдельности:

# %% [markdown]
# ####  Предобработаем столбец name:

# %%
#Выведем на экран столбец name.
print(games["name"])#Как видно из результата,в нем 16715 строк и тип данных object(так как информация о названии игры является строкой,то менять тип данных не нужно)
#Выведем на экран кол-во пропусков в столбце.
print(games["name"].isna().sum())##Как видно из результатов,в столбце 2 пропуска.
# Out:
# 0                           Wii Sports
# 1                    Super Mario Bros.
# 2                       Mario Kart Wii
# 3                    Wii Sports Resort
# 4             Pokemon Red/Pokemon Blue
#                      ...
# 16710    Samurai Warriors: Sanada Maru
# 16711                 LMA Manager 2007
# 16712          Haitaka no Psychedelica
# 16713                 Spirits & Spells
# 16714              Winning Post 8 2016
# Name: name, Length: 16715, dtype: object
# 2

# %% [markdown]
# Название игры это один из самых важных параметров и такие пропуски мы никак заполнить не можем.Формально,мы можем сразу удалить такие строки из датафрейма,но предварительно вывыдем их на экран

# %%
print(games[games["name"].isna()])#Как видно из результатов,данные строки имеют большое кол-во пропусков и в других столбцах,так что можно спокойно их удалить
games = games[games["name"].notna()].reset_index(drop = True)#Удаление строк с пропусками в name и сброс индексов.
#Выведем на экран кол-во пропусков в обновленном столбце.
print(games["name"].isna().sum())##Как видно из результатов,пропусков были удалены.
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно, доля пропусков здесь менее 5% и для экономии времени их можно удалить.
# </div>

# %% [markdown]
# ####  Предобработаем столбец platform:

# %%
#Выведем на экран столбец platform.
print(games["platform"])#Как видно из результата,в нем 16713 строк и тип данных object(так как информация о типе игровой платформы является строкой,то менять тип данных не нужно)
#Выведем на экран кол-во пропусков в столбце.
print(games["platform"].isna().sum())##Как видно из результатов,в столбце 0 пропусков.
# Out:
# 0         Wii
# 1         NES
# 2         Wii
# 3         Wii
# 4          GB
#          ...
# 16708     PS3
# 16709    X360
# 16710     PSV
# 16711     GBA
# 16712     PSV
# Name: platform, Length: 16713, dtype: object
# 0

# %% [markdown]
# Вывод:как видно из результатов,в столбце нет никаких аномалий.

# %% [markdown]
# ####  Предобработаем столбец year_of_release:

# %%
#Выведем на экран столбец year_of_release.
print(games["year_of_release"])#Как видно из результата,в нем 16715 строк и тип данных float.

#Выведем на экран кол-во пропусков в столбце.
print(games["year_of_release"].isna().sum())#Как видно из результатов,в столбце 269 пропусков.
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16708    2016.0
# 16709    2006.0
# 16710    2016.0
# 16711    2003.0
# 16712    2016.0
# Name: year_of_release, Length: 16713, dtype: float64
# 269

# %% [markdown]
# При подробном рассмотрении видно,что данный столбец явлется не полноценной датой,а только годом.Формально,
# само число года не может быть дробным и нам стоило бы его изменить на тип int,но с другой стороны,в столбце есть пропуски,а
# пропуски имеют тип floa64 и  в столбце не может быть одновременно тип int и float.С другой стороны,год выпуска
# игры нельзя заменить никаким медианныи или средним значением,то есть пропуски можно или заполнить точным значением,
# или убрать,или оставить как есть.Так как однозначно заполнить пропуски из достоверных источников мы не можем,то их можно удалить или оставить.
#
# В связи с тем,что у нас порядка 269 пропусков,а это менее 2% от общего числа строк,удалим строки с пропусками в столбце "year_of_release" и так как у нас не останется пропусков в стоблце ,то изменим его тип данных на int:

# %%
games = games[games["year_of_release"].notna()].reset_index(drop = True)#Удаление строк с пропусками в name и сброс индексов.
#Выведем на экран кол-во пропусков в обновленном столбце.
print(games["year_of_release"].isna().sum())#Как видно из результатов,пропусков были удалены.
#Изменим тип данных столбца "year_of_release" на int
games["year_of_release"] = games["year_of_release"].astype("int",errors = "raise")
print(games["year_of_release"])#Как видно из результатов,тип даных был изменен.
# Out:
# 0
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16439    2016
# 16440    2006
# 16441    2016
# 16442    2003
# 16443    2016
# Name: year_of_release, Length: 16444, dtype: int64

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Здесь пропуски также можно удалить за малой долей.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# А затем поменять тип данных, ведь, как ты верно заметил он вряд ли должен быть дробным.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Строки с пропусками удалены.
# - Тип данных изменен.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ####  Предобработаем столбец genre:

# %%
#Выведем на экран столбец genre.
print(games["genre"])#Как видно из результата,в нем 16444 строк и тип данных object(так как информация о жанре игры является строкой,то менять тип данных не нужно)
#Выведем на экран кол-во пропусков в столбце.
print(games["genre"].isna().sum())##Как видно из результатов,в столбце 0 пропусков.
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16439          Action
# 16440          Sports
# 16441       Adventure
# 16442        Platform
# 16443      Simulation
# Name: genre, Length: 16444, dtype: object
# 0

# %% [markdown]
# Вывод:как видно из результатов,в столбце нет никаких аномалий.

# %% [markdown]
# ####  Предобработаем столбец na_sales:

# %%
#Выведем на экран столбец na_sales.
print(games["na_sales"])#Как видно из результата,в нем 16444 строк и тип данных float(так как информация о продажах игры в Северной Америке является дробным числом,то менять тип данных не нужно
#Выведем на экран кол-во пропусков в столбце.
print(games["na_sales"].isna().sum())##Как видно из результатов,в столбце 0 пропусков.
# Out:
# 0        41.36
# 1        29.08
# 2        15.68
# 3        15.61
# 4        11.27
#          ...
# 16439     0.00
# 16440     0.00
# 16441     0.00
# 16442     0.01
# 16443     0.00
# Name: na_sales, Length: 16444, dtype: float64
# 0

# %% [markdown]
# Вывод:как видно из результатов,в столбце нет никаких аномалий.

# %% [markdown]
# ####  Предобработаем столбец eu_sales:

# %%
#Выведем на экран столбец eu_sales.
print(games["eu_sales"])#Как видно из результата,в нем 16444 строк и тип данных float(так как информация о продажах игры в Европе является дробным числом,то менять тип данных не нужно)
#Выведем на экран кол-во пропусков в столбце.
print(games["eu_sales"].isna().sum())##Как видно из результатов,в столбце 0 пропусков.
# Out:
# 0        28.96
# 1         3.58
# 2        12.76
# 3        10.93
# 4         8.89
#          ...
# 16439     0.00
# 16440     0.01
# 16441     0.00
# 16442     0.00
# 16443     0.00
# Name: eu_sales, Length: 16444, dtype: float64
# 0

# %% [markdown]
# Вывод:как видно из результатов,в столбце нет никаких аномалий.

# %% [markdown]
# ####  Предобработаем столбец jp_sales:

# %%
#Выведем на экран столбец jp_sales.
print(games["jp_sales"])#Как видно из результата,в нем 16444 строк и тип данных float(так как информация о продажах игры в Японии является дробным числом,то менять тип данных не нужно)
#Выведем на экран кол-во пропусков в столбце.
print(games["jp_sales"].isna().sum())##Как видно из результатов,в столбце 0 пропусков.
# Out:
# 0         3.77
# 1         6.81
# 2         3.79
# 3         3.28
# 4        10.22
#          ...
# 16439     0.01
# 16440     0.00
# 16441     0.01
# 16442     0.00
# 16443     0.01
# Name: jp_sales, Length: 16444, dtype: float64
# 0

# %% [markdown]
# Вывод:как видно из результатов,в столбце нет никаких аномалий.

# %% [markdown]
# ####  Предобработаем столбец other_sales:

# %%
#Выведем на экран столбец other_sales.
print(games["other_sales"])#Как видно из результата,в нем 16444 строк и тип данных float(так как информация о продажах игры в иных регионах является дробным числом,то менять тип данных не нужно)
#Выведем на экран кол-во пропусков в столбце.
print(games["other_sales"].isna().sum())##Как видно из результатов,в столбце 0 пропусков.
# Out:
# 0        8.45
# 1        0.77
# 2        3.29
# 3        2.95
# 4        1.00
#          ...
# 16439    0.00
# 16440    0.00
# 16441    0.00
# 16442    0.00
# 16443    0.00
# Name: other_sales, Length: 16444, dtype: float64
# 0

# %% [markdown]
# Вывод:как видно из результатов,в столбце нет никаких аномалий.

# %% [markdown]
# ####  Предобработаем столбец critic_score:

# %%
#Выведем на экран столбец critic_score.
print(games["critic_score"])#Как видно из результата,в нем 16444 строк и тип данных float.
#Выведем на экран кол-во пропусков в столбце.
print(games["critic_score"].isna().sum())##Как видно из результатов,в столбце 8576 пропусков.
# Out:
# 0        76.0
# 1         NaN
# 2        82.0
# 3        80.0
# 4         NaN
#          ...
# 16439     NaN
# 16440     NaN
# 16441     NaN
# 16442     NaN
# 16443     NaN
# Name: critic_score, Length: 16444, dtype: float64
# 8461

# %% [markdown]
# Данные параметр(оценка критиков),как и название игры,нельзя заменить никаким примерным значеним,только буквальным.Стоит отметить,что данный параметр измеряют в целых числах,но так как по аналогии со столбцом year_of_release пропуски имеют тип данных float,а в столбце не может быть данных 2 типов, то пропуски трогать не будем.
#
# Выведем для наглядности строк с пропусками в столбце critic_score:

# %%
print(games.query("critic_score.isna()"))
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16439  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16440               LMA Manager 2007     X360             2006        Sports
# 16441        Haitaka no Psychedelica      PSV             2016     Adventure
# 16442               Spirits & Spells      GBA             2003      Platform
# 16443            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# Можно заметить,что в данных строках также есть пропуски в столбцах user_score  и rating.
# Выведем на  экран кол-во строк,где есть пропуски во всех этих столбцах одновременно:

# %%
print(games.query("critic_score.isna() and rating.isna()"))
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16439  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16440               LMA Manager 2007     X360             2006        Sports
# 16441        Haitaka no Psychedelica      PSV             2016     Adventure
# 16442               Spirits & Spells      GBA             2003      Platform
# 16443            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# Вывод:как видно из результата,количество строк с одновременными пропусками в столбцах rating и critic_score практически соответствует кол-ву  общему кол-ву пропусков в столбце rating.Возможную связь рассмотрим далее при предобработке столбца rating,а пока не будем трогать пропуски.

# %% [markdown]
# ####  Предобработаем столбец user_score:

# %%
#Выведем на экран столбец user_score.
print(games["user_score"])#Как видно из результата,в нем 16444 строк и тип данных object(так как информация о пользовательском рейтинге игры является числом ,то менять нужно изменить тип данных на float)
#Выведем на экран кол-во пропусков в столбце.
print(games["user_score"].isna().sum())#Как видно из результатов,в столбце 6605 пропусков.
# Out:
# 0          8
# 1        NaN
# 2        8.3
# 3          8
# 4        NaN
#         ...
# 16439    NaN
# 16440    NaN
# 16441    NaN
# 16442    NaN
# 16443    NaN
# Name: user_score, Length: 16444, dtype: object
# 6605

# %% [markdown]
# При изучении столбца user_score было замечено особое значение tbd,которое согласно интернету расшифровывается как    to be determined(перев."будет определено").Это значит,что значение оценки пользователей должно появиться в будущем,но на данный момент его нет.Исходя из этого,дабы не удалять более 2376 и перевести сам столбец к типу данных float,вызовем метод to_numeric с параметром errors = "coerce" означающим,что все значения,которые при преобразовании типа object в тип  float выдадут ошибку будут принудительно заменены на nan.

# %%
print(len(games.query("user_score == 'tbd'")))#2376 строк со значением tbd
games["user_score"] = pd.to_numeric(games["user_score"],errors = "coerce")#все tbd перевелись в nan
print(games["user_score"].isna().sum())#Как видно из результатов,теперь в столбце 8981 пропусков(6605+2376)
# Out:
# 2376
# 8981

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Решение верное, но в ТЗ нас просят подробней рассмотреть аббревиатуру tbd, что она означает и почему поступаем именно так.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Аргументирована замена tbd на nan.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Верно, `tbd` означает `To Be Determined`, т.к. игра ещё не выпущена. Тут можно заменить заглушкой, а можно привести в nan
# </div>

# %% [markdown]
# ####  Предобработаем столбец rating:

# %%
#Выведем на экран столбец rating.
print(games["rating"])#Как видно из результата,в нем 16713 строк и тип данных object(так как информация о возрастном рейтинге игры является строкой ,то менять тип данных не нужно)
#Выведем на экран кол-во пропусков в столбце.
print(games["rating"].isna().sum())##Как видно из результатов,в столбце 6764 пропусков.
# Out:
# 0          E
# 1        NaN
# 2          E
# 3          E
# 4        NaN
#         ...
# 16439    NaN
# 16440    NaN
# 16441    NaN
# 16442    NaN
# 16443    NaN
# Name: rating, Length: 16444, dtype: object
# 6676

# %% [markdown]
# Одной из возможных причин пропусков может быть факт,что игра старая и на момент ее выхода не было никаких систем выставления рейтинга.Проверим эту гипотезу построив гистограмму по годам:

# %%
games[games["rating"].isna()]["year_of_release"].hist(bins = 100)#Как видно из результатов,данная гипотеза была отвергнута,так как большую часть пропусков имеют игры с датой выхода после 1995 года,а согласно википедии,данная система выставления рейтинга появилась в 1994.
# Out:
# <AxesSubplot:>

# %% [markdown]
# Значение возрастного рейтинга игры нельзя заменить никаким медианныи или средним значением,потому что система формирования рейтинга игры,согласно открытым источникам из интернета,основывается на оценке опреденных критериев отдельно взятой игры(например,наличие крови,насилия,сцен сексуального характера и тд.).В той или иной степени игры определенных жанров имеют некоторые общие пункты,например шутеры могут сцена крови и убийств,с другой,рейтинг выставляется по наличию критериев в сумме,а большинстве своем игры  непохожи друга на друга.Исходя из этого можно было бы предположить,что самый частый рейтинг для жанра (в данному случае,моду) можно подставить на место пропусков ,но нет гарантий,что если пропусков много и подставив такое значение мы не исказим данные.
#
# Исходя из сказанного выше,построим для каждого жанра игры столбчатую диаграмму частоты встречаемости разных рейтингов.Для наглядности под каждой гистограммой выведем кол-во строк такого же жанра,но с пропусками в рейтингах чтобы примерно видеть,как исказится график при подстановке на место пропусков соответсвующих частый рейтинг.

# %%
nan_counts = games[games["rating"].isna()]["genre"].value_counts()
for i in games["genre"].unique():
    games[games["genre"] == i]["rating"].value_counts().plot(kind='bar')
    plt.title(f"Гистограмма частоты встречаемости возрастного рейтинга игр жанра {i}")
    plt.xlabel("Виды возрастного рейтинга")#изменим название оси
    plt.ylabel("Частота")#изменим название оси
    plt.show()
    print(f"Количество пропусков рейтинга жанра {i}:{nan_counts.loc[i]}")
# Out:
# Количество пропусков рейтинга жанра Sports:828
# Количество пропусков рейтинга жанра Platform:317
# Количество пропусков рейтинга жанра Racing:370
# Количество пропусков рейтинга жанра Role-Playing:711
# Количество пропусков рейтинга жанра Puzzle:233
# Количество пропусков рейтинга жанра Misc:859
# Количество пропусков рейтинга жанра Shooter:300
# Количество пропусков рейтинга жанра Simulation:298
# Количество пропусков рейтинга жанра Action:1161
# Количество пропусков рейтинга жанра Fighting:405
# Количество пропусков рейтинга жанра Adventure:853
# Количество пропусков рейтинга жанра Strategy:341

# %% [markdown]
# Как видно из результатов,каждый график сильно исказится,создав на частом значений огромный пик.
#
# Иными возможными причинам отсутвия возрастного рейтинга ESRB могут быть:
# - Это малоизвестные и непопулярные игры и как ,не имеющие возрастного рейтинга,уставновленного ESRB-организацией,ввиду своей неизвестности.
# - ESRB организация находится в США и Канаде и как итог можно предположить,что пропуски имеют игры сделанные ЗА пределами США и Канады.
#
# Исходя из этого,так как мы не можем подставить однозначно правилильное значение и окажется,что игры действительно сделаны не в США,заменим пропуски на значение "unknown" для дальнейшего анализа в проекте.

# %%
games["rating"].fillna("unknown")
# Out:
# 0              E
# 1        unknown
# 2              E
# 3              E
# 4        unknown
#           ...
# 16439    unknown
# 16440    unknown
# 16441    unknown
# 16442    unknown
# 16443    unknown
# Name: rating, Length: 16444, dtype: object

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Что касается рейтинга ESRB,  пропуски в этой колонке не являются просто ошибкой заполнения данных, а несут определенную информацию. Что бы проанализировать ее, на пропуски следует поставить заглушку.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Выдвинута гипотеза о том,что игры с пропусками в rating сделаны не в США.Если это так,то оно подтвердится дальше.
# </div>

# %% [markdown]
# ### Проверим датафрейм на наличие  дубликатов:

# %% [markdown]
# #### Проверим датафрейм на наличие явных дубликатов:

# %%
print(games[games.duplicated()])#Как видно из результатов,явных дубликатов в датафрейме нет
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# #### Проверим датафрейм на наличие неявных дубликатов:

# %% [markdown]
# Возможные виды неявных дубликатов:
#
# - по названию игры;
# - по названию игры и платформе;
# - по названию игры,платформе и году выхода игры.
#
# Первый вариант нельзя отнести к полноценным неявным дубликатам,так как одна и та же игра может выйти на разные платформы как в один год,так и разные,но формально это две разные игры с одним названием,но разными рейтингами,продажами и т.д.
#
# Второй вариант также нельзя отнести к полноценным неявным дубликатам,так как одна и та же игра с одной и той же платформой может выйти в разные годы,это называется ремейком или ребутом.В первом случае это та же игра с измененными параметрами,в основном с улучшенным качеством.Во втором это перезапуск игр,то есть буквально другая игра с некоторыми элементами предшественницы и таким же названием.
#
# Третий вариант уже можно отнести к своего роду неявным дубликатам и ,если такие игры имеются и имеют разные значения в продажах,то эти строки можно заменить одной с суммами продаж по регионам.Проверим датафрейм на наличие таких дубликатов:

# %%
print(games.loc[games[['name', 'platform','year_of_release']].duplicated(keep=False)])#Как видно из результатов,у нас имеется 2  такие строки
buffer_dataframe = games#Сохраним старый датафрейм для проверки правильности агрегации.

games = games.groupby(['name', 'platform','year_of_release']).agg({"genre":"first","na_sales":"sum","eu_sales":"first","jp_sales":"sum","other_sales":"sum","critic_score":"first","user_score":"first","rating":"first"}).reset_index()#Проагрегируем датафрейм по столбцам с продажами по регионами с сохраненим значений других столбцов

display(games)# выведем обновленный датафрейм.Как видно из результатов,наш датафрейм отсортировался по значениям столбца name.Строк стало на 1 меньше,как нужно.
display(buffer_dataframe[buffer_dataframe["name"] == " Fire Emblem Fates"])#Выведем значение из старого датафрейма для сравнения с такой же строкой из обновленного.Как видно из результатов,все впорядке
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 600    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 15969  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating
# 600         0.0         0.23          83.0         5.5      E
# 15969       0.0         0.00          83.0         5.5      E
#                                name platform  year_of_release         genre  \
# 0                    Beyblade Burst      3DS             2016  Role-Playing
# 1                 Fire Emblem Fates      3DS             2015  Role-Playing
# 2              Frozen: Olaf's Quest      3DS             2013      Platform
# 3              Frozen: Olaf's Quest       DS             2013      Platform
# 4        Haikyu!! Cross Team Match!      3DS             2016     Adventure
# ...                             ...      ...              ...           ...
# ...

# %% [markdown]
# Вывод:во время предобработки данных было сделано

# %% [markdown]
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
games["total_sales"] = games["other_sales"] + games["jp_sales"] + games["eu_sales"] + games["na_sales"] 
display(games.head(10))
# Out:
#                                       name platform  year_of_release  \
# 0                           Beyblade Burst      3DS             2016
# 1                        Fire Emblem Fates      3DS             2015
# 2                     Frozen: Olaf's Quest      3DS             2013
# 3                     Frozen: Olaf's Quest       DS             2013
# 4               Haikyu!! Cross Team Match!      3DS             2016
# 5                        Tales of Xillia 2      PS3             2012
# 6                              '98 Koshien       PS             1998
# 7               .hack//G.U. Vol.1//Rebirth      PS2             2006
# 8             .hack//G.U. Vol.2//Reminisce      PS2             2006
# 9  .hack//G.U. Vol.2//Reminisce (jp sales)      PS2             2006
#
#           genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 0  Role-Playing      0.00      0.00      0.03         0.00           NaN
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Колонка с общими продажами создана.
#
# Также, мы можем работать с набором столбцов:</font><br>
# `data = data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)`
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
#
# * Отсутствует проверка явных дубликатов, а это основа предобработки данных.
#
#
# * Также мы можем проверить наличие неявных дубликатов. Неявные дубликаты могут появиться в случаях, когда данные собирались из разных источников или в системе были какие-то сбои при логировании. Я пометил этот момент красным, для того, что бы мы попрактиковались в этом, также это пригодится в следующих проектах.
#
# Сделать это можно так: мы уже привели названия столбцов к нижнему регистру, теперь проведем вот такую проверку `data[data[['name', 'platform','year_of_release']].duplicated(keep=False)]`
#
# Попробуй, пожалуйста, реализовать и сделать заключение, есть ли неявные дубликаты и что мы можем с ними сделать :)
#
#
# * К сожалению отсутствует промежуточный вывод о проделанной работе в разделе. Дополни, пожалуйста
# </div>

# %% [markdown]
# Вывод:во время предобработки данных было сделано:
#
# - Названия столбцов приведены к нижнем регистру;
# - Изменены типы данных в столбцах year_of_release(с float на int) и user_score(с object на float);
# - В столбцах name и year_of_release были удалены строки с пропусками;
# - В столбцах user_score были обработаны значения типа tbd(заменены на nan);
# - В столбцах user_score и critic_score пропуски были оставлены без изменений;
# - В столбце rating пропуски были заменены на значениц uknown для дальнейшего анализа;
# - Выполнена проверка на наличие явных дубликатов(отсутствовали);
# - Выполнена проверка на наличие неявных дубликатов (все дубликаты были агрегированы);
# - Добавлен столбец total_sales со значением глобальных продаж одной игры.

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Написан вывод.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Линейный график количества   игр по годам:

# %%
line_graph_dataframe = games.groupby("year_of_release").agg({"name":"count"}).reset_index()
plt.plot(line_graph_dataframe["year_of_release"],line_graph_dataframe["name"])
plt.title("Линейный график количества игр по годам")
plt.ylabel("Количество игр за год")#изменим название оси
plt.xlabel("Год выпуска игр")#изменим название оси
plt.show()

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# При работе с временными данными, особенно когда речь идет о визуализации, важно выбирать правильные методы представления информации.
#
# * Линейные графики и столбчатые диаграммы - лучший выбор для временных рядов. Они показывают динамику изменений во времени и позволяют легко уловить тренды и аномалии.
#
# * Гистограммы - полезны для демонстрации распределения данных. Однако нужно быть осторожным при использовании гистограмм для временных данных. Неправильный выбор интервалов может исказить восприятие данных. Если использовать гистограмму, то необходимо тщательно выберать интервалы.
#
#
#
# Ключ к успешной визуализации - в понимании датасета и выборе правильных инструментов для демонстрации ключевой информации.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Насколько я могу судить,в нашем случае лучше использовать гистограмму,дабы видеть общую динамику выпуска игр по годам,то есть ,последовательно,а не выводя условны рейтинг от лучших лет  по числовому значению до худших.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Ты верно подметил: важно показать динамику по годам, а не просто частотное распределение. Но именно поэтому `value_counts().plot(kind='bar')` — не самый подходящий способ. Этот метод по умолчанию сортирует ось X по убыванию значений, то есть по количеству игр, а не по порядку лет, и получается не динамика, а рейтинг.
#
# Когда ты работаешь с временными рядами (в нашем случае годы выпуска игр), лучше всего использовать линейный график или столбчатую диаграмму с хронологической осью X. Это позволит отследить динамику изменения во времени: рост, падения, тренды.
#
# Если мы хотим показать, сколько игр выходило каждый год, построй график, где по оси X — года, а по оси Y — количество выпущенных игр. Это даст наглядное представление о том, как развивалась индустрия.
#
# Главное убедиться, что года идут по порядку, а не по убыванию популярности (как делает value_counts()), и тогда график будет действительно полезен и корректен для анализа.
#
# Таким образом, твоя мысль о том, что важно видеть общую картину по годам, абсолютно верна, но текущее решение её не отражает.
#
#
# **Гистограмма — это инструмент распределения числовых значений по интервалам, а не по категориям вроде лет. Здесь она не подходит по смыслу.**
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Гистограммы заменены на линейный графики в соответствии с вашими рекомендациями.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# Вывод:как видно из результатов,что до 1995 кол-во игр было очень маленьким,что можно объяснить тем,что к тому моменту идустрия цифровых игр была достаточно молода и как итог ограниченность знаний и возможностей в их производстве.Также причиной может быть и то,что в тот момент электронная техника была недостаточно развита для массового создания и использования цифровых игр.Исходя из этого,данные до 1995 года имеют для исследования малую ценность.
#
# Отдельно нужно отметить,что на 2008-2009 год пришелся пик выпуска игр,за которые последовал достаточной большой спад.Это может быть связано с экономической ситуаций в мире(Мировой экономический кризис 2008—2013 года) или появление большого количества новых игровых платформ и исчезновением старых.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Все же можно сказать, что рост начался в 1995г и все, что до этого периода нас интересвет мало.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Вывод изменен в соответсвии с вашими рекомендациями.
# </div>

# %% [markdown]
# ### Изучим, как менялись продажи по платформам:

# %%
platform_total_sales = games.groupby("platform").agg({"total_sales":"sum"}).sort_values(by = "total_sales",ascending = False)
top_platforms_total_sales = platform_total_sales.nlargest(11,"total_sales")#Датафрейм из агрегированного с 5-ю самыми популярным игровыми платформами
print(top_platforms_total_sales)
# Out:
#           total_sales
# platform
# PS2           1233.56
# X360           961.24
# PS3            931.33
# Wii            891.18
# DS             802.78
# PS             727.58
# PS4            314.14
# GBA            312.88
# PSP            289.53
# 3DS            257.81
# PC             255.76

# %% [markdown]
# В соответсвии с результатами,в топах по продажах на разных платформах,исходя из имеющихся данных,находятся одни консоли(стационарные и портативные).В соответствии с условиями задания,нам нужно проанализировать по годам самые популярные платформы.В данном случае,нужно проверить платформы в с продажами выше 500 млн копий.Также видно,что в топах по продажам находятся все консоли линейки PS(Playstation),причем лидирующую позицию занимает PS2.
#
# Стоит отдельно заметить,что продажи на PC(персональные компьютеры) меньше 300 млн копий,хотя,объективно,в отличии от многих видов консолей,которые подразумевают выпуск своей техники с фиксированными  параметрами и как итог,они ограничены в перспективе выхода новых игр,так как консоли нельзя улучшать.ПК же явлется нефиксированной в плане параметров технической единицей,так как  все его составляющие легкозаменяемы,а значит он имеет неограниченный потенциал для работы будущих игр.В добавок стоит сказать,что несмотря на это,компьютерные игры имеют меньшие продажи.Это может быть связано с несколькими причинами:
#
# 1)Размер.Большая часть консолей имеют компактный размер и ,как итог, могут также как и мобильные телефоны браться в любое место,а ПК(ноутбуки исключение) имеют большие габариты;
#
# 2)Иной первоначальный смысл.Компьютер в большинстве своем покупается как универсальная мощная вычислительная техника,выполняющая множество разнообразных функций,где игры не являются основополагающими.В отличии от него,консоли покупаются с одной единственной целью - игры;
#
# 3)Цена.Компьютер будет стоить дороже любых переносных консолей,но вполне может стоять в одном ценовом сегменте со стационарными консолями,например PS(PlayStation)всех серий  или XBOX;
#
# 4)Эксклюзивы.Не все игры,выходящие на одни платформы выходят на другие.
#
# Все эти возможные причины могут комбинироваться и зависеть друг от друга.Исходя из универсальности и больших перспектив в плане реализации игровой индустрии на персональные компьютеры (PC),будем анализировать все платформы до PC включительно.
#
# Выведем линейные графики для всех значений до PC включительно.

# %% [markdown]
# #### Линейный график количества игр на платформе  PS2 по годам :

# %% [markdown]
# Для автоматизации процесса,создадим функцию с выводом линейного графика:

# %%
def platform_line_graph(platform):
    line_graph_dataframe = games[games["platform"]==platform].groupby("year_of_release").agg({"name":"count"}).reset_index()
    plt.figure(figsize = (10,6))
    plt.grid(linestyle = "--")
    plt.title(f"Линейный график количества игр на платформе {platform} по годам")
    plt.ylabel(f"Количество игр на платформе {platform} за год")#изменим название оси
    plt.xlabel("Год выпуска игр")#изменим название оси
    plt.plot(line_graph_dataframe["year_of_release"],line_graph_dataframe["name"],marker = "o")
    plt.show()

# %%
platform_line_graph("PS2")

# %% [markdown]
# Вывод:как видно из результатов,данная платформа достигла своего пика в 2003 году и после этого постепенно падала до 2011 года,после которого игры больше не выходили.Если посмотреть одновременно на графики PS2 и PS3,то можно заметить,что с появление и ростам производства игр на PS3 ,производство на PS2 неуклонно падает,вплоть до полного прекращаения в 2012 году.Это связано с тем,что платформа устарела и на ее место полностью заняла более новая PS3.

# %% [markdown]
# #### Линейный график количества игр на платформе  X360 по годам :

# %%
platform_line_graph("X360")

# %% [markdown]
# Вывод:как видно из результатов,данная платформа достигла своего пика в 2011 году и после этого постепенно падала до 2016 года. года.Это связано с тем,что платформа устарела и на ее место постепенно занимает  более новая XboxOne,которая не попала в этот топ.

# %% [markdown]
# #### Линейный график количества игр на платформе  PS3 по годам :

# %%
platform_line_graph("PS3")

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Обрати, пожалуйста, внимание, что наши действия повторяются с точки зрения кода и хорошо бы автоматизировать процесс.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Написана функция для вывода графика.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Супер!
# </div>

# %% [markdown]
# Вывод:как видно из результатов,данная платформа достигла своего пика в 2011 году и после этого начала постепенно падать .Если посмотреть одновременно на графики PS3 и PS4,то можно заметить,что с появление и ростам производства игр на PS3 ,производство на PS2 неуклонно падает.Это связано с тем,что платформа устарела и на ее место постепенно занимает более новая PS4.

# %% [markdown]
# #### Линейный график количества игр на платформе  Wii по годам :

# %%
platform_line_graph("Wii")

# %% [markdown]
# Вывод:как видно из результатов,данная платформа достигла своего пика в 2009 году и после этого  начала постепенно падать .Стоит заметить,что несмотря на очень малые выпуски игр после 2013 года,окончательно до 2016 года игр выпускать не перестали.

# %% [markdown]
# #### Линейный график количества игр на платформе  DS по годам :

# %%
platform_line_graph("DS")

# %% [markdown]
# Вывод:как видно из результатов,данная платформа достигла своего пика в 2008 году и после этого постепенно падала до 2013 года,после которого игры больше не выходили.Отдельного внимания заслуживает отметка на 1985 году.Данное значение явлется аномальным и ошибочным,так как платформа Nintendo DS вышла в 2004 году.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Стоит обратить внимание на платформу DS. Там всего 2 точки: 1985 и 2004. Вряд ли игры не продавались 20 лет. Возможно это ошибка, так как в 1985 году этой платформы еще не существовало. Визуализация помогает не только определять закономерности, но еще и находить ошибки.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Вывод изменен.
#
# </div>

# %% [markdown]
# #### Линейный график количества игр на платформе  PS по годам :

# %%
platform_line_graph("PS")

# %% [markdown]
# Вывод:как видно из результатов,данная платформа достигла своего пика в 1998 году и после этого начала постепенно падать а до 2003 года,после которого игры больше не выходили.Если посмотреть одновременно на графики PS и PS2,то можно заметить,что с появление и ростам производства игр на PS2 ,производство на PS неуклонно падает.Это связано с тем,что платформа устарела и на ее место постепенно занимает более новая PS2.

# %% [markdown]
# #### Линейный график количества игр на платформе  GBA по годам :

# %%
platform_line_graph("GBA")

# %% [markdown]
# Вывод:как видно из результатов,данная платформа достигла своего пика в 2002 году и после этого постепенно падала до 2007 года,после которого игры больше не выходили.

# %% [markdown]
# #### Линейный график количества игр на платформе  PS4 по годам :

# %%
platform_line_graph("PS4")

# %% [markdown]
# Вывод:как видно из результатов,данная платформа была выпущена 2013 году и только начинает набирать популярность.

# %% [markdown]
# #### Линейный график количества игр на платформе  PSP по годам :

# %%
platform_line_graph("PSP")

# %% [markdown]
# Вывод:как видно из результатов,данная платформа была выпущена 2004,имела два пика в 2006 и 2010 годах,но после этого постепенно падала до 2015 года,после которого игры больше не выходили.

# %% [markdown]
# #### Линейный график количества игр на платформе  PC по годам :

# %%
platform_line_graph("PC")

# %% [markdown]
# Вывод:как видно из результатов,в отличии от всех платформ ,изученных  выше,игры для ПК выпускались на протяжении всех лет с пиками или падениями.Данная платформа развивается и потенциально не исчезнет из-за устаревания и как итог,игры для нее будут создаваться.
#
# Подведем общий итог по графикам:
# - Срок от появления до забвения PS2 : 2000-2011;
# - Срок от появления X360 : 2005 - 2016 (настоящий момент);
# - Срок от появления PS3 : 2006 - 2016 (настоящий момент);
# - Срок от появления Wii : 2006 - 2016 (настоящий момент);
# - Срок от появления до забвения DS : 2004-2013;
# - Срок от появления до забвения PS : 1994-2003;
# - Срок от появления до забвения GBA : 2000-2007;
# - Срок от появления PS4 : 2013 - 2016 (настоящий момент);
# - Срок от появления до забвения PSP : 2004-2015;
# - Срок от появления PC : 1985 - 2016 (настоящий момент).
#
# Исходя из этих цифр можно прийти к выводу,что средний срок "жизни" игровой платформы 7-12 лет.Исходя из этого и самих графиков можно сказать,что платформы X360,PS3,Wii с каждым следующим годом будут выпускать все меньше и меньше игр и в течении ближайших 2-4 лет должны прекратить их выпускать.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# А как мы можем ответить на вопрос ТЗ: "За какой характерный срок появляются новые и исчезают старые платформы?", т.е. какой жизненный цикл плафторм мы можем назвать?
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# На данный вопрос я написал вывод ниже и , как я понимаю,вы на него написали зеленый комментарий.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Нет, там речь идет про актуальный период, по которому мы делаем прогноз, а здесь речь о анализе жизненного цикла платформ, т.е. сколько лет в среднем они "живут" на рынке. Например, жизненный цикл PS2 составляет почти 13 лет, а что мы можем сказать в целом о жизненном цикле патформ? Расчеты выше вполне помогают нам это проанализировать и ответить на поставленный в ТЗ вопрос.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Вывод написан выше.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Исследуем,какие платформы лидируют по продажам, растут или падают за  актуальный период.

# %% [markdown]
# Определим,что мы будем относить к "актуальному периоду".Как было видно из результатов всех гистограмм пункта 3.2,в основном на старые платформы прекращали выпускать игры в период с 2010 по 2013 год,примерно в это же время появлялись новые платформы.Исходя из этого,за актуальный период возьмем игры,начиная с 2013 года.В соответсвии с условиями задания,учитывайть в работе данные за предыдущие годы мы не будем.

# %%
actual_period_games = games.query("year_of_release >= 2013")
platform_total_sales = actual_period_games.groupby("platform").agg({"total_sales":"sum"}).sort_values(by = "total_sales",ascending = False)
print(platform_total_sales)
# Out:
#           total_sales
# platform
# PS4            314.14
# PS3            181.43
# XOne           159.32
# 3DS            143.25
# X360           136.80
# WiiU            64.63
# PC              39.43
# PSV             32.99
# Wii             13.66
# PSP              3.50
# DS               1.54

# %% [markdown]
# Вывод:как видно из результатов,лидером по продажам за актуальный период является PS4.В соответствии с тем,что в пункте 3.2.8 мы убедились,что данная платформа новая в своей линейке(PS- PlayStation) и имеет линейный рост по продажам ,можно предположить,что данная платформа в будущем будем иметь большие продажи.
#
# На втором месте стоит платформа PS3,но в соответствии с результатами пункта 3.2.3 ,данная платформа переживает постепенный спад популярности и на основании платформ прошлый версий линейки PS  можно спрогнозировать ей дальнейший спад с постепенным забвением.
#
# На третьем месте стоит платформа XOne.Данная платформа молодая и является наследницей успешной платформы X360(Xbox 360).Исходя их этого ,она имеет хороший потенциал для продаж.
#
#
# На четвертом месте стоит платформа 3DS(Nintendo 3DS).Данная платформа,как и платформы выше,является молодой и следующей в линейке платформ DS(Nintendo DS).Можно предположить,что в будущем она будет иметь большие продажи.
#
#
# Исходя из сказанного выше,потенциально покупаемыми будут игры на платформах Ps4,XOne,3Ds.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно. Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватим уже отжившие тренды. Но и очень короткий период не подходит для прогнозирования, так что надо выбирать золотую середину (но не менее 2-х полных лет и не более 5 лет).
# </div>

# %% [markdown]
# ### Исследуем глобальные продажи игр  по  топовым платформам за актуальный период.

# %% [markdown]
# Для лучшей наглядности продаж игр по платформам,будем выводить полную(со всеми выбросами),частичную(задаваемую параметрами пользователя,подразумевая значения границ статистически значимой выборки) и описательную статистику.
#
# Создадим функцию для вывода диграммы размаха:

# %%
def platform_full_boxplot(platform):#функция для вывода полной диграммы размаха
    actual_period_games[actual_period_games["platform"]== platform].boxplot("total_sales");
    plt.title(f"Диаграмма размаха глобальных продаж игр на платформ {platform} ")
    plt.ylabel(f"Глобальные продажи игр на платформе {platform}")#изменим название оси
    plt.show()
    
def platform_partial_boxplot(platform,l_side = 0, r_side = 2):#функция для вывода частичной диграммы размаха
    actual_period_games[actual_period_games["platform"]== platform].boxplot("total_sales");
    plt.title(f"Диаграмма размаха глобальных продаж игр на платформ {platform} ")
    plt.ylabel(f"Глобальные продажи игр на платформе {platform}")#изменим название оси
    plt.ylim(l_side,r_side)
    plt.show()

# %% [markdown]
# #### Платформа PS4:

# %%
platform_full_boxplot("PS4")

# %%
platform_partial_boxplot("PS4")
print(actual_period_games.query("platform == 'PS4'")["total_sales"].describe())
# Out:
# count    392.000000
# mean       0.801378
# std        1.609456
# min        0.010000
# 25%        0.060000
# 50%        0.200000
# 75%        0.730000
# max       14.630000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,1.73 млн проданных копий,с медианой в значении 0.2 млн копий и верхним квартилем в значении 0.73 млн копий.Значение std в 1.6 означает,что данные достаточно сильно разбросаны,относительно среднего значения.

# %% [markdown]
# #### Платформа PS3:

# %%
platform_full_boxplot("PS3")

# %%
platform_partial_boxplot("PS3")
print(actual_period_games.query("platform == 'PS3'")["total_sales"].describe())
# Out:
# count    345.000000
# mean       0.525884
# std        1.451939
# min        0.010000
# 25%        0.040000
# 50%        0.150000
# 75%        0.510000
# max       21.050000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,1.20 млн проданных копий,с медианой в значении 0.15 млн копий и верхним квартилем в значении 0.51 млн копий.Значение std в 1.45 означает,что данные достаточно сильно разбросаны,относительно среднего значения.

# %% [markdown]
# #### Платформа Xone:

# %%
platform_full_boxplot("XOne")

# %%
platform_partial_boxplot("XOne")
print(actual_period_games.query("platform == 'XOne'")["total_sales"].describe())
# Out:
# count    247.000000
# mean       0.645020
# std        1.036139
# min        0.010000
# 25%        0.060000
# 50%        0.220000
# 75%        0.685000
# max        7.390000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,1.6 млн проданных копий,с медианой в значении 0.22 млн копий и верхним квартилем в значении 0.51 млн копий.Значение std в 1.03 означает,что данные достаточно средне разбросаны,относительно среднего значения.

# %% [markdown]
# #### Платформа 3DS:

# %%
platform_full_boxplot("3DS")

# %%
platform_partial_boxplot("3DS")
print(actual_period_games.query("platform == '3DS'")["total_sales"].describe())
# Out:
# count    303.000000
# mean       0.472772
# std        1.381347
# min        0.010000
# 25%        0.040000
# 50%        0.090000
# 75%        0.280000
# max       14.600000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,0.68 млн проданных копий,с медианой в значении 0.09 млн копий и верхним квартилем в значении 0.27 млн копий.Значение std в 1.38 означает,что данные достаточно сильно разбросаны,относительно среднего значения.

# %% [markdown]
# #### Платформа X360:

# %%
platform_full_boxplot("X360")

# %%
platform_partial_boxplot("X360")
print(actual_period_games.query("platform == 'X360'")["total_sales"].describe())
# Out:
# count    186.000000
# mean       0.735484
# std        1.663275
# min        0.010000
# 25%        0.080000
# 50%        0.265000
# 75%        0.795000
# max       16.270000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,0.77 млн проданных копий,с медианой в значении 0.26 млн копий и верхним квартилем в значении 0.795 млн копий.Значение std в 1.66 означает,что данные  сильно разбросаны,относительно среднего значения.

# %% [markdown]
# #### Платформа WiiU:

# %%
platform_full_boxplot("WiiU")

# %%
platform_partial_boxplot("WiiU")
print(actual_period_games.query("platform == 'WiiU'")["total_sales"].describe())
# Out:
# count    115.000000
# mean       0.562000
# std        1.038778
# min        0.010000
# 25%        0.060000
# 50%        0.200000
# 75%        0.595000
# max        7.090000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,1.29 млн проданных копий,с медианой в значении 0.2 млн копий и верхним квартилем в значении 0.795 млн копий.Значение std в 1.04 означает,что данные  средне разбросаны,относительно среднего значения.

# %% [markdown]
# #### Платформа PC:

# %%
platform_full_boxplot("PC")

# %%
platform_partial_boxplot("PC")
print(actual_period_games.query("platform == 'PC'")["total_sales"].describe())
# Out:
# count    189.000000
# mean       0.208624
# std        0.352304
# min        0.010000
# 25%        0.030000
# 50%        0.080000
# 75%        0.230000
# max        3.050000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,0.52 млн проданных копий,с медианой в значении 0.08 млн копий и верхним квартилем в значении 0.23 млн копий.Значение std в 0,35 означает,что данные  слабо разбросаны,относительно среднего значения.

# %% [markdown]
# #### Платформа PSV:

# %%
platform_full_boxplot("PSV")

# %%
platform_partial_boxplot("PSV")
print(actual_period_games.query("platform == 'PSV'")["total_sales"].describe())
# Out:
# count    358.000000
# mean       0.092151
# std        0.153816
# min        0.010000
# 25%        0.020000
# 50%        0.040000
# 75%        0.110000
# max        1.960000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,0.24 млн проданных копий,с медианой в значении 0.04 млн копий и верхним квартилем в значении 0.11 млн копий.Значение std в 0,15 означает,что данные  очень  слабо разбросаны,относительно среднего значения.

# %% [markdown]
# #### Платформа Wii:

# %%
platform_full_boxplot("Wii")

# %%
platform_partial_boxplot("Wii")
print(actual_period_games.query("platform == 'Wii'")["total_sales"].describe())
# Out:
# count    23.000000
# mean      0.593913
# std       0.915432
# min       0.010000
# 25%       0.045000
# 50%       0.180000
# 75%       0.755000
# max       3.580000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,0.75 млн проданных копий,с медианой в значении 0.18 млн копий и верхним квартилем в значении 0.75 млн копий.Значение std в 0,91 означает,что даные средне разбросаны относительно среднего значения.

# %% [markdown]
# #### Платформа PSP:

# %%
platform_full_boxplot("PSP")

# %%
platform_partial_boxplot("PSP")
print(actual_period_games.query("platform == 'PSP'")["total_sales"].describe())
# Out:
# count    67.000000
# mean      0.052239
# std       0.059768
# min       0.010000
# 25%       0.015000
# 50%       0.020000
# 75%       0.070000
# max       0.240000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,0.2 млн проданных копий,с медианой в значении 0.02 млн копий и верхним квартилем в значении 0.07 млн копий.Значение std в 0,05 означает,что даные очень слабо разбросаны относительно среднего значения.

# %% [markdown]
# #### Платформа DS:

# %%
platform_full_boxplot("DS")

# %%
platform_partial_boxplot("DS")
print(actual_period_games.query("platform == 'DS'")["total_sales"].describe())
# Out:
# count    8.000000
# mean     0.192500
# std      0.172026
# min      0.030000
# 25%      0.067500
# 50%      0.150000
# 75%      0.252500
# max      0.510000
# Name: total_sales, dtype: float64

# %% [markdown]
# Вывод:как видно из результатов,на полной диаграмме размаха имеется большое кол-во аномальных значений с большими продажами,выходящими за пределы статистически значимой выборки.Этот итог закономерен,так как игры не имеют строгих правил относительно их продаж,иначе говоря,отдельно взятые игры могут становиться хитами и как итог иметь непрапорционально огромные продажи,чем медианное значение по платформам.Сама статистическая выборка ограничена значениями  в 0,0.51 млн проданных копий,с медианой в значении 0.15 млн копий и верхним квартилем в значении 0.25 млн копий.Значение std в 0,17 означает,что даные очень слабо разбросаны относительно среднего значения.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
#
# * К сожалению, на этих графиках видны только выбросы, и совсем не видны медиана и 75% квантиль. Для более обоснованных выводов нужно сделать дополнительный график, где будет отображена только нижняя часть boxplot-ов. Этого можно добиться, например, задав параметр ylim.
#
#
# * Не стоит ограничивать диаграмму размаха, нам нужно посмотреть все платформы из актуального периода.
#
#
# * Прошу тебя построить одну диаграмму с несколькими ящиками платформ на одной оси, пример ниже.
#
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Построены диаграммы размаха для всех платформ за актуальный период;
# - Для каждой платформы построены дополнительные графики для анализа;
# - Переписаны выводы;
# - Построена общая диграмма для всех платформ.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Хорошая работа!
# </div>

# %% [markdown]
# #### Общая диаграмма размаха по платформам за актуальный период:

# %%
platform_list = ["PS4","PS3","XOne","3DS","X360","WiiU","PC","PSV","Wii","PSP","DS"]
plt.boxplot([ actual_period_games[actual_period_games["platform"] == i ]["total_sales"] for i in platform_list])
plt.title(f"Диаграмма размаха глобальных продаж игр на платформах {','.join(platform_list)} ")
plt.xticks([i for i in range(1,12)],platform_list)
plt.ylabel("Глобальные продажи игр")#изменим название оси
plt.ylim(0,2)#Определим условную границу для максималного значения статистически значимой выборки
plt.show()

# %% [markdown]
# Вывод:анализируя график с диаграммами размаха по игровым платформам за актуальный период можно заметить,что практически все диаграммы имеют выбросы,являющиеся игровыми хитами по платформам.Многи из этих хитов могут быть одними и теми же играми,портированными на разные платформы.Стоит обратить внимани на то,что некоторые платформы имеют большие статистически значемые выборки(болишие "усы" у диаграмм).Данная информация говорит о достаточно большом разбросе данных относительно среднего значения,но также может означать и общие высокие продажи на платформе.К ним относятся платформа PS4(новая),XOne(новая,хотя имеет значения чуть меньше,чем у X360, ввиду своего недавнего выхода),WiiU(новая,ситуация аналогичная с XOne),X360(предшественница XOne,в будущем ее продажи будут падать по мере замещения рынка XOne),Wii(аналогично X360).

# %% [markdown]
# ### Изучим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.

# %% [markdown]
# ####  Диаграмма рассеяния влияния  на продажи  игр популярной платформы PS4  отзывов критиков:

# %%
actual_period_games.query("platform == 'PS4'").plot(x='total_sales', y='critic_score', kind='scatter')#Построим диаграмму зависимости
plt.title("Диаграмма рассеяния влияния на продажи игр популярной платформы PS4 отзывов критиков")
plt.ylabel("Оценка критиков")#изменим название оси
plt.xlabel("Глобальные продажи игр")#изменим название оси
plt.show()
actual_period_games.query("platform == 'PS4'")['total_sales'].corr(actual_period_games.query("platform == 'PS4'")["critic_score"] )#Посчитаем коэффициент корреляции Пирсона
# Out:
# 0.4065679020617813

# %% [markdown]
# Вывод:как видно из результата,между продажами игр и оценками критиков существует средняя связь.

# %% [markdown]
# ####  Диаграмма рассеяния влияния  на продажи  игр популярной платформы PS4  отзывов  пользователей:

# %%
actual_period_games.query("platform == 'PS4'").plot(x='total_sales', y='user_score', kind='scatter')#Построим диаграмму зависимости
plt.title("Диаграмма рассеяния влияния на продажи игр популярной платформы PS4 отзывов пользователей")
plt.ylabel("Оценка критиков")#изменим название оси
plt.xlabel("Глобальные продажи игр")#изменим название оси
plt.show()
actual_period_games.query("platform == 'PS4'")['total_sales'].corr(actual_period_games.query("platform == 'PS4'")["user_score"] )#Посчитаем коэффициент корреляции Пирсона
# Out:
# -0.03195711020455638

# %% [markdown]
# Вывод:как видно из результата,между продажами игр и оценками пользователей связь отсутвует,то есть продажи игр не зависят от оценки пользователей.

# %% [markdown]
# ####  Диаграмма рассеяния влияния  на продажи  игр популярной платформы XOne  отзывов критиков:

# %%
actual_period_games.query("platform == 'XOne'").plot(x='total_sales', y='critic_score', kind='scatter')#Построим диаграмму зависимости
plt.title("Диаграмма рассеяния влияния на продажи игр популярной платформы XOne отзывов критиков")
plt.ylabel("Оценка критиков")#изменим название оси
plt.xlabel("Глобальные продажи игр")#изменим название оси
plt.show()
actual_period_games.query("platform == 'XOne'")['total_sales'].corr(actual_period_games.query("platform == 'XOne'")["critic_score"] )#Посчитаем коэффициент корреляции Пирсона
# Out:
# 0.4169983280084019

# %% [markdown]
# Вывод:как видно из результата,между продажами игр и оценками критиков существует слабая связь.

# %% [markdown]
# ####  Диаграмма рассеяния влияния  на продажи  игр популярной платформы XOne  отзывов пользователей:

# %%
actual_period_games.query("platform == 'XOne'").plot(x='total_sales', y='user_score', kind='scatter')#Построим диаграмму зависимости
plt.title("Диаграмма рассеяния влияния на продажи игр популярной платформы XOne отзывов пользователей")
plt.ylabel("Оценка критиков")#изменим название оси
plt.xlabel("Глобальные продажи игр")#изменим название оси
plt.show()
actual_period_games.query("platform == 'XOne'")['total_sales'].corr(actual_period_games.query("platform == 'XOne'")["user_score"] )#Посчитаем коэффициент корреляции Пирсонапользователей
# Out:
# -0.06892505328279426

# %% [markdown]
# Вывод:как видно из результата,между продажами игр и оценками пользователей связь отсутвует,то есть продажи игр не зависят от оценки пользователей.

# %% [markdown]
# ####  Диаграмма рассеяния влияния  на продажи  игр популярной платформы 3DS отзывов критиков:

# %%
actual_period_games.query("platform == '3DS'").plot(x='total_sales', y='critic_score', kind='scatter')#Построим диаграмму зависимости
plt.title("Диаграмма рассеяния влияния на продажи игр популярной платформы 3DS отзывов критиков")
plt.ylabel("Оценка критиков")#изменим название оси
plt.xlabel("Глобальные продажи игр")#изменим название оси
plt.show()
actual_period_games.query("platform == '3DS'")['total_sales'].corr(actual_period_games.query("platform == '3DS'")["critic_score"] )#Посчитаем коэффициент корреляции Пирсона
# Out:
# 0.35705661422881046

# %% [markdown]
# Вывод:как видно из результата,между продажами игр и оценками критиков существует слабая связь.

# %% [markdown]
# ####  Диаграмма рассеяния влияния  на продажи  игр популярной платформы 3DS отзывов пользователей:

# %%
actual_period_games.query("platform == '3DS'").plot(x='total_sales', y='user_score', kind='scatter')#Построим диаграмму зависимости
plt.title("Диаграмма рассеяния влияния на продажи игр популярной платформы 3DS отзывов пользователей")
plt.ylabel("Оценка критиков")#изменим название оси
plt.xlabel("Глобальные продажи игр")#изменим название оси
plt.show()
actual_period_games.query("platform == '3DS'")['total_sales'].corr(actual_period_games.query("platform == '3DS'")["user_score"] )#Посчитаем коэффициент корреляции Пирсона
# Out:
# 0.24150411773563013

# %% [markdown]
# Вывод:как видно из результата,в отличии от платформ PS4 и XOne,между продажами игр и оценками пользователей существует  очень слабая связь ,то есть продажи игр очень слабо зависят оценки пользователей,но все же зависят.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Исходя из значений корреляций можно сказать, что  оценка критиков имеет слабое влияние на продажи, оценка пользователей на продажи не влияет.
#
#
# Рекомендую пользоваться вот такой шпаргалкой для более точного толкования значений корреляции.
#
#
# ![%D1%88%D0%BF%D0%B0%D1%80%D0%B3%D0%B0%D0%BB%D0%BA%D0%B0%20%D0%BA%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D0%B9.jpg](attachment:%D1%88%D0%BF%D0%B0%D1%80%D0%B3%D0%B0%D0%BB%D0%BA%D0%B0%20%D0%BA%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D0%B9.jpg)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Интерпретации изменены в соответствии с вашими рекомендациями.
# </div>

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# #### Диаграмма размаха глобальных продаж  игр разных жанров за актуальный период

# %%
genre_list = ["Role-Playing","Platform","Adventure","Misc","Sports","Action","Simulation","Strategy","Shooter","Fighting","Racing","Puzzle"]
plt.boxplot([ actual_period_games[actual_period_games["genre"] == i ]["total_sales"] for i in genre_list])
plt.title(f"Диаграмма размаха глобальных продаж игр жанров {','.join(genre_list)} ")
plt.xticks([i for i in range(1,13)],genre_list,rotation = 45)
plt.ylabel("Глобальные продажи игр")#изменим название оси
plt.ylim(0,10)#Определим условную границу для максималного значения статистически значимой выборки
plt.show()

# %% [markdown]
# #### Столбчатая диаграмм количества игр разных жанров за актуальный период

# %%
actual_period_games_tota_sales = actual_period_games.groupby("genre").agg({"total_sales":"count"}).sort_values(by = "total_sales",ascending = False)
actual_period_games_tota_sales.plot(kind='bar');#создадим столбчатую диаграмму
plt.title("Столбчатая диаграмм количества игр разных жанров за актуальный период")
plt.ylabel("Частота встречаемости игр по жанрам")#изменим название оси
plt.xlabel("Жанр игр")#изменим название оси
plt.show()

# %% [markdown]
# Вывод:как видно из результатов,самым популярным жанром по количеству произведенных игр  с большим отрывом является Action,вторым жанр Role-Playing(меньше в 2 раза,чем Action).Самый непопулярным по количеству игр,является жанр Puzzle.Отдельно стоит обратить внимание на жанр Shooter(игр почти в 4 раза меньше,чем у жанра Action).
#
# По глобальным продажам картина иная:самую большую статистически значимую выборку,с большим отрывом от остальных жанров и самым большим средним и медианным значениями,имеет жанра Shooter.Далее идет жанр Sports и Platform.Жанра Action,несмотря на самое больше кол-во игр из жанров,имеет одни из самых низких значений статистической выборки и самое большое количество выбросов(хитов).Ситуацию с жанром Action можно объяснить тем,что несмотря на большое кол-во игр,в среднем они пользуются низкой популярностью и подавляющую долю продаж формируют за счет своих хитов.
#
# Исходя из сказанно выше,самым выгодным в плане количества игр/общие продажи является жанр Shooter.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи. Лучше всего нам это покажет boxplot.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ## Составление портрета пользователя каждого региона:

# %% [markdown]
# Определим для пользователя каждого региона (NA, EU, JP):
#
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# ### Япония

# %% [markdown]
# #### Самые популярные платформы (топ-5):

# %%
buf_data_jp = actual_period_games.groupby("platform").agg({"jp_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам платформ
top_platforms_jp = buf_data_jp.nlargest(5,"jp_sales")#Датафрейм из агрегированного с 5-ю самыми популярным игровыми платформами
other_sum = buf_data_jp.sum() - top_platforms_jp.sum()#Подсчет общей суммы все остальных платформ
top_platforms_jp = top_platforms_jp.append(pd.Series({"jp_sales":other_sum["jp_sales"]},name = "Other"))#добавление строк с общей суммой иных платформ
top_platforms_jp["jp_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по платформам
plt.title("Круговая диграмма соотношения игровых платформ в Японии")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()
print(f"Общее количество игровых платформ: {len(buf_data_jp)}")#Общее кол-во игровых платформ
# Out:
# Общее количество игровых платформ: 11

# %% [markdown]
# Вывод:как видно из результата,5 самых популярных платформ из 11 (3DS,PS3,PSV,PS4,WiiU)составляют более 97% продаж от всего рынка цифровых игр в Японии.Все эти платформы относятся к консолям.Стоит отдельно заметить,что все эти платформы созданы и производятся в самой Японии.

# %% [markdown]
# #### Самые популярные жанры (топ-5):

# %%
buf_data_jp = actual_period_games.groupby("genre").agg({"jp_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам жанров
top_genres_jp = buf_data_jp.nlargest(5,"jp_sales")#Датафрейм из агрегированного с 5-ю самыми популярным игровыми жанрами
other_sum = buf_data_jp.sum() - top_genres_jp.sum()#Подсчет общей суммы все остальных жанров
top_genres_jp = top_genres_jp.append(pd.Series({"jp_sales":other_sum["jp_sales"]},name = "Other"))#добавление строк с общей суммой иных жанров
top_genres_jp["jp_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по жанрам
plt.title("Круговая диграмма соотношения игровых жанров в Японии")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()
print(f"Общее количество игровых жанров: {len(buf_data_jp)}")#Общее кол-во игровых жанров
# Out:
# Общее количество игровых жанров: 12

# %% [markdown]
# Вывод:как видно из результата,5 самых популярных игровых жанров из 12 (Action,Role-Playing,Shooter,Fighting,Misc)составляют более 80% продаж от всего рынка цифровых игр в Японии.Стоит обратить внимание на то,что самый популярный жанр игр,у которого большой разрыв с иными жанрами, Role-Playing имеет долю 36,26% от всех игр.

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в отдельном регионе:

# %%
buf_data_jp = actual_period_games.groupby("rating").agg({"jp_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам возрастного рейтинга
buf_data_jp["jp_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по видам возрастного рейтинга
plt.title("Круговая диграмма соотношения видов возрастного рейтинга")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()

# %% [markdown]
# Вывод:как видно из результата,самое большое значение в 36.95% имеют игры с возрастным рейтингом Т(подростки,от 13 лет).Далее идут игры с рейтингом Е(для всех,ранее от 6 лет) в 27.17%.Все это может быть связано с тем,что все  популярные  в Японии жанры игр имеют малое кол-во критериев,определеяющее возратной рейтинг (кровь,насилие и тд).Для жанра Е эти параметры скорее всего относятся к фэнтезийным существам,что соответсвует мультипликационного или мягкому насилию.Также причина может быть связана с тем,что в сами игры чаще играют дети и подростки.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Исходя из расчетов вывод верный, но, портреты пользователей нам также необходимостроить по актуальному периоду. После  корректировки данные могут поменяться, а соответственно и выводы.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Данные взяты за актуальный период.
# - Выводы изменены для регионов изменены.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Северная Америка

# %% [markdown]
# #### Самые популярные платформы (топ-5):

# %%
buf_data_na = actual_period_games.groupby("platform").agg({"na_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам платформ
top_platforms_na = buf_data_na.nlargest(5,"na_sales")#Датафрейм из агрегированного с 5-ю самыми популярным игровыми платформами
other_sum = buf_data_na.sum() - top_platforms_na.sum()#Подсчет общей суммы все остальных платформ
top_platforms_na = top_platforms_na.append(pd.Series({"na_sales":other_sum["na_sales"]},name = "Other"))#добавление строк с общей суммой иных платформ
top_platforms_na["na_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по платформам
plt.title("Круговая диграмма соотношения игровых платформ в Северной Америки")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()
print(f"Общее количество игровых платформ: {len(buf_data_na)}")#Общее кол-во игровых платформ
# Out:
# Общее количество игровых платформ: 11

# %% [markdown]
# Вывод:как видно из результата,5 самых популярных платформ из 11 (XOne,PS3,PS4,3DS,X360)составляют более 88% продаж от всего рынка цифровых игр в Северной Америке.Все эти платформы относятся к консолям.Стоит отдельно заметить,что 3 из 5 этих платформы созданы и производятся в Японии,при этом самая популярная платформа из этих 5ти PS4  в 24.84%,создана  и производится в Японии.

# %% [markdown]
# #### Самые популярные жанры (топ-5):

# %%
buf_data_na = actual_period_games.groupby("genre").agg({"na_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам жанров
top_genres_na = buf_data_na.nlargest(5,"na_sales")#Датафрейм из агрегированного с 5-ю самыми популярным игровыми жанрами
other_sum = buf_data_na.sum() - top_genres_na.sum()#Подсчет общей суммы все остальных жанров
top_genres_na = top_genres_na.append(pd.Series({"na_sales":other_sum["na_sales"]},name = "Other"))#добавление строк с общей суммой иных жанров
top_genres_na["na_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по жанрам
plt.title("Круговая диграмма соотношения игровых жанров в Северной Америке")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()
print(f"Общее количество игровых жанров: {len(buf_data_na)}")#Общее кол-во игровых жанров
# Out:
# Общее количество игровых жанров: 12

# %% [markdown]
# Вывод:как видно из результата,5 самых популярных игровых жанров из 12 (Action,Role-Playing,Sports,Platform,Misc)составляют более 85% продаж от всего рынка цифровых игр в Северной Америке.Стоит обратить внимание на то,что самый популярный жанр игр, Action имеет долю 28.8% от всех игр.Далее идет жанр Shooter с результатом 25.07%

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в отдельном регионе:

# %%
buf_data_na = actual_period_games.groupby("rating").agg({"na_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам возрастного рейтинга
buf_data_na["na_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по видам возрастного рейтинга
plt.title("Круговая диграмма соотношения видов возрастного рейтинга")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()

# %% [markdown]
# Вывод:как видно из результата,самое большое значение в 47.43% имеют игры с возрастным рейтингом М (mature,17+).Это значение
# почти в два раза, чем в Японии.Далее идут игры с рейтингом Е(для всех,ранее от 6 лет) с результатом в 22.7%.

# %% [markdown]
# ### Европа

# %% [markdown]
# #### Самые популярные платформы (топ-5):

# %%
buf_data_eu = actual_period_games.groupby("platform").agg({"eu_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам платформ
top_platforms_eu = buf_data_eu.nlargest(5,"eu_sales")#Датафрейм из агрегированного с 5-ю самыми популярным игровыми платформами
other_sum = buf_data_eu.sum() - top_platforms_eu.sum()#Подсчет общей суммы все остальных платформ
top_platforms_eu = top_platforms_eu.append(pd.Series({"eu_sales":other_sum["eu_sales"]},name = "Other"))#добавление строк с общей суммой иных платформ
top_platforms_eu["eu_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по платформам
plt.title("Круговая диграмма соотношения игровых платформ в Европе")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()
print(f"Общее количество игровых платформ: {len(buf_data_eu)}")#Общее кол-во игровых платформ
# Out:
# Общее количество игровых платформ: 11

# %% [markdown]
# Вывод:как видно из результата,5 самых популярных платформ из 11 (PS4,PS3,XOne,X360,3DS)составляют более 85% продаж от всего рынка цифровых игр в Европе.Все эти платформы относятся к консолям.Стоит отдельно заметить,что 3 из 5 этих платформы созданы и производятся в Японии,и две (Xbox 360 и Xbox One) в США,а самая популярная платформа PS4 с результатом в 35.97% создана и производится в Японии.Также стоит обратить внимание,что в общей картине ситуация повторяет продажи по платформа в Северной Америке.Это может быть связано с тем,что культурно население Европы и Северной Америки похоже и как результат,продажи в масштабе схожи.

# %% [markdown]
# #### Самые популярные жанры (топ-5):

# %%
buf_data_eu = actual_period_games.groupby("genre").agg({"eu_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам жанров
top_genres_eu = buf_data_eu.nlargest(5,"eu_sales")#Датафрейм из агрегированного с 5-ю самыми популярным игровыми жанрами
other_sum = buf_data_eu.sum() - top_genres_eu.sum()#Подсчет общей суммы все остальных жанров
top_genres_eu = top_genres_eu.append(pd.Series({"eu_sales":other_sum["eu_sales"]},name = "Other"))#добавление строк с общей суммой иных жанров
top_genres_eu["eu_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по жанрам
plt.title("Круговая диграмма соотношения игровых жанров в Европе")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()
print(f"Общее количество игровых жанров: {len(buf_data_eu)}")#Общее кол-во игровых жанров
# Out:
# Общее количество игровых жанров: 12

# %% [markdown]
# Вывод:как видно из результата,5 самых популярных игровых жанров из 12 (Action,Role-Playing,Sports,Racing,Misc)составляют более 80% продаж от всего рынка цифровых игр в Европе.Стоит обратить внимание на то,что самый популярный жанр игр, Action имеет долю 30.12% от всех игр.Вдобавок здесь повторяется ситуация из пункта 4.2.2,что по общей форме результаты сильно похожи на результаты для Северной Америки(кроме того,что в Европе в топ-5 вошли гонки (racing),а в Северной Америке платформеры(misc).Это может быть связано с тем,что культурно население Европы и Северной Америки похоже и как результат,продаже в масштабе похожи.

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в Европе:

# %%
buf_data_eu = actual_period_games.groupby("rating").agg({"eu_sales":"sum"})#Создание агрегированного датафрейма из исходного по видам возрастного рейтинга
buf_data_eu["eu_sales"].plot.pie(autopct = "%1.2f%%")#Построение круговой диограммы по видам возрастного рейтинга
plt.title("Круговая диграмма соотношения видов возрастного рейтинга")
plt.ylabel("Доля от общего числа игр")#изменим название оси
plt.show()

# %% [markdown]
# Вывод:как видно из результата,самое большое значение в 46.38%  имеют игры с возрастным рейтингом М (mature,17+).Это значение
# почти в два раза, чем в Японии и практически идентично значению в Северной Америке.Далее идут игры с рейтингом Е(для всех,ранее от 6 лет) с результатом в 26.61%.Вдобавок здесь повторяется ситуация из пункта 4.2.3,что по общей форме результаты сильно похожи на результаты для Северной Америки

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# В процессе предобработки данных мы не учли отсутствующие значения в рейтинге ESRB, что привело к исключению игр без рейтинга из анализа. Однако анализ продаж таких игр может выявить ключевые особенности различных регионов.
#
# Изучив специфику рейтинга ESRB, становится ясно, что он применяется главным образом для игр, реализуемых в США и Канаде. Отсюда и отсутствие рейтинга для игр в других регионах. Важно помнить, что каждая цифра в датасете отражает определенные бизнес-процессы. Поэтому в процессе предобработки следует подойти к вопросу глобальнее, заменяя пропущенные значения на, например, `Unknown`, чтобы учесть все игры при последующем анализе.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Хотя пропуски в столбце rating и были заменены на unknown,на круговой диаграмме это не отобразилось.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# За исключением временного интервала портреты пользователй построены верно и получены ответы на поставленные вопросы. Но еще раз напоминаю, что после корректировки актуального периода возможно выводы придется скорректировать.
# </div>

# %% [markdown]
# ##  Проверка гипотез

# %% [markdown]
# ### Проверим гипотезу о том,равны ли средние пользовательские рейтинги платформ Xbox One и PC

# %% [markdown]
# Гипотезы для проверки будут иметь следующий вид:
#
# Альтернативная гипотеза — двусторонняя:
#
# - H0:μ(пользовательский рейтинг платформы Xbox ) = μ(пользовательский рейтинг платформы PC )
# - H1:μ(пользовательский рейтинг платформы Xbox) != μ(пользовательский рейтинг платформы PC)
#
#
# В нашем случае,генеральные совокупности рейтингов платформ Xbox One и PC будут иметь разные размеры,а значит для проверки гипотез для двух генеральный совокупностей мы будем использовать метод st.ttest_ind с параметро equal_var = False.
#
# Так как метод ttest_ind чувствителен к пропускам,удалим их из выборок для анализа

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Гипотезы сформулированы верно.
# </div>

# %%
alpha = 0.05#Критерий статистической значимости

results = st.ttest_ind(actual_period_games.query("platform == 'XOne'")["user_score"].dropna(), actual_period_games.query("platform == 'PC'")["user_score"].dropna(),equal_var=False)
print(f'p-value: {results.pvalue}')
    # проверяем p-value
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
print("Средний пользовательский рейтинг игр платформы XOne:",actual_period_games.query("platform == 'XOne'")["user_score"].mean())
print("Средний пользовательский рейтинг игр платформы PC:",actual_period_games.query("platform == 'PC'")["user_score"].mean())
# Out:
# p-value: 0.14759594013430324
# Нет оснований отвергнуть нулевую гипотезу
# Средний пользовательский рейтинг игр платформы XOne: 6.521428571428572
# Средний пользовательский рейтинг игр платформы PC: 6.269677419354839

# %% [markdown]
# Вывод:как видно из результатов,нулевая гипотеза о равенстве средних не была отвергнута.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Тест проведен корректно, но не по актуальному периоду, а прогноз мы строим именно по нему.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Гипотезы проверены за актуальный период.
# - Добавлены строки с выводом среднего пользовательского рейтинга по платформам.
# - Выводы изменены.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Теперь все верно
# </div>

# %% [markdown]
# ### Проверим гипотезу о том,равны ли средние пользовательские рейтинги  жанров Action и Sports

# %% [markdown]
# Гипотезы для проверки будут иметь следующий вид:
#
# Альтернативная гипотеза — двусторонняя:
#
# - H0:μ(пользовательский рейтинг жанра Action ) = μ(пользовательский рейтинг жанра Sports )
# - H1:μ(пользовательский рейтинг жанра Action) != μ(пользовательский рейтинг жанра Sports)
#
# В нашем случае,генеральные совокупности рейтингов жанров Action и Sports будут иметь разные размеры,а значит для проверки гипотез для двух генеральный совокупностей мы будем использовать метод st.ttest_ind с параметро equal_var = False.
#
# Так как метод ttest_ind чувствителен к пропускам,удалим их из выборок для анализа

# %%
alpha = 0.05#Критерий статистической значимости

results = st.ttest_ind(actual_period_games.query("genre == 'Action'")["user_score"].dropna(), actual_period_games.query("genre == 'Sports'")["user_score"].dropna(),equal_var=False)
print(f'p-value: {results.pvalue}')
    # проверяем p-value
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
print("Средний пользовательский рейтинг игр жанра Action:",actual_period_games.query("genre == 'Action'")["user_score"].mean())
print("Средний пользовательский рейтинг игр жанра Sports:",actual_period_games.query("genre == 'Sports'")["user_score"].mean())
# Out:
# p-value: 1.4460039700704315e-20
# Отвергаем нулевую гипотезу
# Средний пользовательский рейтинг игр жанра Action: 6.837532133676093
# Средний пользовательский рейтинг игр жанра Sports: 5.238124999999999

# %% [markdown]
# Вывод:как видно из результатов,нулевая гипотеза о равенстве средних рейтингов жанров Action и Sports была отвергнута.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Аналогично
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# * Правильно, что для тестирования гипотез использован двусторонний t-тест Стьюдента.
# * Хорошо, что использован параметр отфильтровывющий пропуски.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также можно вывести не только pvalue, но еще и средние значения выборок, которые мы изучаем. Это позволит нам проверить не ошиблись ли мы, если они расходятся с тестом Стьюдента.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# - Гипотезы проверены за актуальный период.
# - Добавлены строки с выводом среднего пользовательского рейтинга по жанрам.
# - Выводы изменены.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению отсутствует очень важная часть исследования - общий вывод о проделанной работе в проекте. Прошу тебя его добавить.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Вывод будет написан после этого ревью.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Супер! Тогда жду версию с оставшимися правками и общим выводом.
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# В целом, работа выполнена качественно: ключевые этапы проработаны, на вопросы из ТЗ даны корректные ответы. После внесения ряда уточнений и корректировок проект будет выглядеть более цельным и профессиональным.
#
# Рекомендую обратить внимание на оформление и структуру кода — старайся использовать функции и циклы, чтобы избежать дублирования и упростить чтение.
#
# Я оставил несколько обязательных замечаний и после их устранения проект будет готов к принятию.
#
# Удачи в доработке, жду финальную версию!

# %% [markdown]
# ## Итоговый вывод:
#
# Во время выполнения Сборного проекта проводился анализ по продажам компьютерных игр интернет-магазина "Стримчик" . В нашем распоряжении имеются данные из открытых источников о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation)
#
#
# ### На  этапе "Загрузка данных" было сделано:
#
# 1) Загружены данные из csv-файла и создан датафрейм **games** с данными об играх(название,год выпуска,жанр,игровая платформа,продажи в Японии,продажи в Северной Америке,продажи в Европе,продажи в остальный регионах,возрастной рейтинг ESRB,оценки пользователей,оценки критиков).
#
# ### На этапе "Предобработка данных" была проделана работа:
#
# 1) Названия столбцов приведены к нижнему регистру;
#
# 2) Изменены типы данных в столбцах year_of_release (с float на int) и user_score(с object на float);
#
# 3) В столбцах name и year_of_release были удалены строки с пропусками;
#
# 4) В столбцах user_score были обработаны значения типа tbd(заменены на nan);
#
# 5) В столбцах user_score и critic_score пропуски были оставлены без изменений;
#
# 6) В столбце rating пропуски были заменены на значениц uknown для дальнейшего анализа;
#
# 7) Выполнена проверка на наличие явных дубликатов(отсутствовали);
#
# 8) Выполнена проверка на наличие неявных дубликатов (все дубликаты были агрегированы);
#
# 9) Добавлен столбец total_sales со значением глобальных продаж одной игры.
#
#
#
# ### На этапе "Исследовательский анализ данных" была описана и визуализирована общая информация о играх и поездках и были сделаны следующие выводы:
#
#
# - За период с 1985 по 2016 год **самой популярной** и массовой в плане продаж стала платформа **PS3** (Японская) с результатом более **1233 млн** проданных копий видеоигр.Второй по продажам стала платформа X360 (США) с результатом 961 млн проданных копий.
#
# - На основании информации,полученной из линейных графиков по платформам за период 1985-2016 год было выявлено,что средний **срок "жизни" платформы** состоявляет порядка **7-12 лет**(исключение составляет PC ,так как персональные компьютеры имеют нефиксированные системные характеристики,а также являются универсальными многофункциональными устройствами,предназначенные в первую очередь для работы).
#
# - На основании изложенной выше информации и выверенных опытным путем принципов,для дальнейшего анализа был определен **"актульный период" - 2013-2016 год**.
#
# - Анализируя информацию по платформа за актуальный период было выявлено,что **самой прибыльной** является платформа **PS4** с результатом 314 млн. проданный копий видеоигр.
#
# - Исходя из информации,полученной при анализе всех платформ за актуальный период было выявлено,что **самые высокие** "средние" продажи имеют платформы **PS4,X360,XOne,WiiU,Wii**.
#
# - Основываясь на  информации,полученной из анализа платформ за актуальный период был сделан вывод,что **потенциально прибыльными** в ближайшие несколько лет станут игры на платформах **PS4,XOne,3DS**.
#
# - При анализе влияния на продажи  игр популярных платформ PS4,XOne,3DS отзывов **критиков** было выявлено,что они **слабо влияют** на продажи игр(коэффициент корреляции Пирсона порядка 0.3-0.5.
#
# - При анализе влияния на продажи  игр популярных платформ PS4,XOne,3DS отзывов **пользователей** было выявлено,что они **не влияют** влияют на продажи игр(коэффициент корреляции Пирсона около 0).
#
# - Самым массовым жанром видеоигр за актуальный период является жанр **Action** (более 770 игр).Далее идут игры жанра Role-Playing ( около 300),Adventure(около 260),Sports (220),Shooter(200).
#
# - **Самые высокие** "средние" продажи имеет жанр **Shooter**,далее жанры Sports и Platform.Жанр Action,несмотря на самое большое кол-во игр,имеет одно из самых низких значений средних продаж,однако одно из самых большое количество аномальных значений (хитов),выбивающихся за пределы статистически значимой выборки.
#
# - **Самым выгодным и перспективным** жанром из расчета глобальные продажи/количество выпущенных игр и по средним продажам ,является жанр **Shooter**.Далее идет жанр Sports.
#
#
#
# ### На этапе "Составление портрета пользователя каждого региона" были сделаны следующие выводы:
#
# #### Япония(JP):
#
# - **5 самых популярных платформ** из 11 (3DS - 48.17% ,PS3 - 16.59%,PSV - 13.21%,PS4 - 11.34% ,WiiU- 7.73%) составляют более 97% продаж от всего рынка цифровых игр в Японии.Все эти платформы относятся к консолям,созданы и производятся в самой Японии.
#
# - **5 самых популярных игровых жанров** из 12 (Role-Playing - 36.26%,Action - 28.76%,Misc - 6.54%,Fighting - 5.45%,Shooter - 4.70%)составляют более 80% продаж от всего рынка цифровых игр в Японии.Стоит обратить внимание на то,что самые популярные жанры игр Role-Playing с долей в 36.26%  и Action с долей в  28.76%,имеют большой разрыв с иными жанрами.
#
# - **самое большое значение** в 36.95% имеют игры с возрастным рейтингом Т(подростки,от 13 лет).Далее идут игры с рейтингом Е(для всех,ранее от 6 лет) в 27.17%, M (взрослые ,от 17 лет) - 25.32%,E10+ (от 10 лет и старше) - 10.57%.
#
# #### Северная Америка(NA):
#
# - **5 самых популярных платформ** из 11 (PS4 - 24.84%,XOne - 21.27%,X360 - 18.66%,PS3 - 14.51%,3DS - 8.73%) составляют более 88% продаж от всего рынка цифровых игр в Северной Америке.3 из 5  платформ созданы и производятся в Японии(PS4,PS3,3DS) и 2 в США (XOne,X360),при этом самая популярная платформа из этих 5-ти PS4  в 24.84% родом из Японии.
#
# - **5 самых популярных игровых жанров** из 12 (Action - 28.8%,Shooter - 25.07%,Sports - 14.91%,Role-Playing - 10.6%,Misc - 6.28%)составляют более 85% продаж от всего рынка цифровых игр в Северной Америке.Стоит обратить внимание на то,что самый популярный жанр игр, Action имеет долю 28.8% от всех игр.Далее идет жанр Shooter с результатом 25.07%.В Северной Америке жанр Shooter гораздо популярнее,чем в Японии.
#
# - **самое большое значение** в 47.43% имеют игры с возрастным рейтингом М (mature,17+).Это значение почти в два раза, чем в Японии.Далее идут игры с рейтингом Е(для всех,ранее от 6 лет) с результатом в 22.7%,E10+ (от 10 лет и старше) - 15.57%, T (от 13 лет и старше ) - 14.3%.
#
# #### Европа (EU):
#
# - **5 самых популярных платформ** из 11 (PS4 - 35.97%,PS3 - 17.29% ,XOne - 13.15% ,X360 - 10.84%,3DS - 7.89%) составляют более 85% продаж от всего рынка цифровых игр в Европе.3 из 5  платформ созданы и производятся в Японии(PS4,PS3,3DS) и 2 в США (XOne,X360).Самая популярная платформа PS4 с результатом в 35.97% родом из Японии.Стоит обратить внимание,что в общей картине ситуация повторяет продажи по платформам в Северной Америке.Это может быть связано с тем,что культурно население Европы и Северной Америки похоже  и как результат,продажи в масштабе схожи.
#
# - **5 самых популярных игровых жанров** из 12 (Action - 30.12%,Shooter - 22.4%,Sports - 15.43%,Role-Playing - 9.43%,Racing - 5.15%) составляют более 80% продаж от всего рынка цифровых игр в Европе.Здесь повторяется ситуация ,что по общей форме результаты сильно похожи на результаты для Северной Америки(кроме того,что в Европе в топ-5 вошли гонки (racing),а в Северной Америке разное(misc).
#
# - **самое большое значение** в 46.38%  имеют игры с возрастным рейтингом М (mature,17+).Это значение почти в два раза больше, чем в Японии, и практически идентично значению в Северной Америке.Далее идут игры с рейтингом Е(для всех,ранее от 6 лет) с результатом в 26.61%,E10+ (от 10 лет и старше) - 13.63%,T (от 13 лет и старше ) - 13.39%.Вдобавок здесь повторяется ситуация ,что по общей форме результаты сильно похожи на результаты для Северной Америки.
#
# ### На этапе "Проверка гипотез" было сделано:
# 1)По актуальным данным проверена гипотеза о том,равны ли средние пользовательские рейтинги платформ Xbox One и PC.По результатам анализа,нулевая гипотеза о равенстве средних  не была отвергнута.
#
# 2)По актуальным данным проверена гипотеза о том,равны ли средние пользовательские рейтинги  жанров Action и Sports.По результатам анализа,нулевая гипотеза о равенстве средних рейтингов жанров Action и Sports была отвергнута в пользу  альтернативной двусторонней гипотезы о неравенстве средних рейтингов жанров Action и Sports.
#
# ### Исходя из проведенного во время выполнения Сборного проекта анализа можно сделать следующие выводы:
#
# - В ближайшие годы перспективными в плане реализации продукции являются игры на платформе PS4.Далее идут платформы XOne,3DS;
#
# - Самым прибыльным без учета аномальных значений по продажам(хитов) явлеется жанр Shooter.Далее  идут жанры Sports,Platform,Racing и Role-Playing;

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# ✍
# Не совсем понятен вывод о исследовательской части из другого проекта. Прошу тебя актуализировать общий вывод согласно данному проекту. А таже расписать общий вывод по пунктам всей проделанной работы.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Прошу прощения.У меня во время написания вывода и оформления работы сайт выдал ошибку и вся работа обнулилась)))А часть из старой работы была взята исключительно как готовый шаблон для пунктов.
#
# - Переписан вывод.
# - Изменено вступление.
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Сейчас все отлично!
#
# Спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊
